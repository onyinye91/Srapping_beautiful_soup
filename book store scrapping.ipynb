# %%
import requests

# %%
url = 'https://www.bookdepository.com/search?searchTerm=python&search=Find+book'

# %%
r = requests.get(url)

# %%
print(r.text[:100])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
#     <link rel="preconnect" href="https://d3ogvdx946i4sr.clo

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="preconnect"/>
#   <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="dns-prefetch"/>
#   <script type="text/javascript">
#    function csmWidgetStart(widgetName) {
#             if (typeof uet == 'function') {
#                 uet('bb', widgetName, {wb: 1});
#             }
#         }
#         function csmWidgetEnd(widgetName) {
#             if (typeof uet == 'function') {
#                 uex('ld', widgetName, {wb: 1});
#             }
#         }
#   </script>
#   <noscript>
#    <style>
#     .hide-when-no-js {
#                 display: none !important;
#             }
#
#             .show-when-no-js {
#                 display: block !important;
#             }
#    </style>
#   </noscript>
#   <script type="text/javascript">
#    csmWidgetStart("optimizelySnippetLoadTime");
#   </script>
#   <script src="https://cdn.optimizely.com/js/8322250184.js">
#   </script>
# ...

# %%
results = soup.findAll('', attrs = {'class': 'item-info'})
len(results)
# Out:
# 30

# %%
for name in soup.find_all('',{'itemprop':'name'}):
    print(name.get('content'))
# Out:
# Python Crash Course (2nd Edition)
# None
# Automate The Boring Stuff With Python
# None
# Python Pocket Reference
# None
# Python for Data Analysis, 2e
# None
# Fluent Python
# None
# Python For Kids
# None
# Learning Python
# None
# Learn Python 3 the Hard Way
# None
# Introduction to Machine Learning with Python
# None
# Deep Learning with Python
# None
# Python Data Science Handbook
# None
# Learn Python the Hard Way
# None
# Automate The Boring Stuff With Python, 2nd Edition
# None
# Black Hat Python
# None
# Python Programming for the Absolute Beginner, Third Edition
# None
# Python Cookbook: No. 3
# None
# Programming Python
# None
# Head First Python 2e
# None
# Computer Coding Python Projects for Kids
# None
# Think Python, 2e
# None
# Effective Python
# None
# The Python Years
# None
# Effective Python
# None
# Violent Python
# None
# Python for Everybody
# None
# Python For Dummies
# None
# Computer Coding Python Games for Kids
# None
# ...

# %%
result_one = results[0]
result_one
# Out:
# <div class="item-info">
# <h3 class="title">
# <a href="/Python-Crash-Course-2nd-Edition-Eric-Matthes/9781593279288?ref=grid-view&amp;qid=1594156199780&amp;sr=1-1">
#                     Python Crash Course (2nd Edition)</a>
# </h3>
# <p class="author">
# <span itemprop="author" itemscope="Eric Matthes" itemtype="http://schema.org/Person">
# <a href="/author/Eric-Matthes" itemprop="url">
# <span itemprop="name">Eric Matthes</span>
# </a>
# </span>
# </p>
# <div class="rating-wrap">
# <a aria-label="Ratings for Python Crash Course (2nd Edition)" href="/Python-Crash-Course-2nd-Edition-Eric-Matthes/9781593279288?ref=grid-view&amp;qid=1594156199780&amp;sr=1-1">
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# </a>
# </div>
# <p class="published" itemprop="datePublished">
#                 09 May 2019</p>
# ...

# %%
#name_of_book = result_one.find('h3').text[22:-1]
#name_of_book
#results.find('h3').text[22:-1]
new_item = []
data_list = []
for item in soup.findAll('',{'itemprop':'name'}):
    new_item.append(item.get('content'))
data_list.append(new_item)

# %%
#author = result_one.find('span').text[2:-2]
#author
new_item = []
for item in soup.findAll('',{'itemprop',"contributor"}):
    new_item.append(item.get('content'))
data_list.append(new_item)

# %%
#date = result_one.find('p', attrs = {'class':'published'}).text[20:]
#date
new_item = []
for item in soup.findAll('',{'class':'published'}):
    new_item.append(str(item)[-15:-4])
data_list.append(new_item)

# %%
#books = []
#for result in results:
#    book_name = results.find('h3').text[22:-1]
#    Author = results.find('span').text[2:-2]
#    publication_date = results.find('p', attrs = {'class':'published'}).text[20:]
#    books.append((book_name,Author,publication_date))
#print(books)

# %%
import pandas as pd

# %%
books_depository = pd.DataFrame(data_list , columns = ['book_name','Author','Publication_date'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-77-a9878f3edc45> in <module>
# ----> 1 books_depository = pd.DataFrame(data_list , columns = ['book_name','Author','Publication_date'])
#
# ~\Anaconda3\anaconda\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     385                     if is_named_tuple(data[0]) and columns is None:
#     386                         columns = data[0]._fields
# --> 387                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     388                     columns = _ensure_index(columns)
#     389
#
# ~\Anaconda3\anaconda\lib\site-packages\pandas\core\frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    7473     if isinstance(data[0], (list, tuple)):
#    7474         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# ...

# %%
books_depository
# Out:
#                            book_name Author Publication_date
# 0  Python Crash Course (2nd Edition)                May 2019
# 1  Python Crash Course (2nd Edition)                May 2019
# 2  Python Crash Course (2nd Edition)                May 2019
# 3  Python Crash Course (2nd Edition)                May 2019
